# %%
import plotly.graph_objects as go
import plotly.express as px
from plotly.subplots import make_subplots
import plotly.figure_factory as ff
import numpy as np
import pandas as pd
from sklearn.preprocessing import StandardScaler
import plotly.io as pio
pio.templates.default = "plotly_white"

# %%
df = pd.read_csv("C:/25-26_R07_NARANJA/Datos/Transformados/df_limpio.csv")
df.columns
df.head
# Out:
# <bound method NDFrame.head of            ID  Edad  Ingresos  Monto_Inicial  Scoring_Crediticio  \
# 0      S97R7X    18     16000           5000                 397
# 1      RLGTBY    50     62116          37278                 486
# 2      SKE2P9    37     37602          44532                 765
# 3      E2FB1D    56     67410          23752                 643
# 4      TKSCGH    35     35930          28440                 645
# ...       ...   ...       ...            ...                 ...
# 50839  G5QJ7O    54     34694          11345                 501
# 50840  FKB7Z1    35     53194          27149                 378
# 50841  O5PRET    57     50658          41656                 645
# 50842  WZEOVA    53     66601          12391                 400
# 50843  O0VB8P    66     38477          12995                 436
#
#        Meses_Empleo  Num_Creditos  Ratio_Interes  Duracion  \
# 0                19             1           8.06        48
# 1               217             3          21.96        12
# 2               150             3          11.20        60
# 3               369             1          21.24        24
# 4               136             3          16.95        12
# ...             ...           ...            ...       ...
# 50839           307             3          22.44        36
# 50840           115             4          18.21        60
# 50841           346             4          18.84        24
# 50842           274             1           3.35        12
# 50843           431             2          21.98        24
#
#        Ratio_Deuda_Ingresos  ...  Posesion_Hipoteca  Personas_Cargo  Fiador  \
# 0                      0.10  ...                  1               0       0
# 1                      0.55  ...                  1               0       1
# 2                      0.23  ...                  1               1       1
# 3                      0.18  ...                  0               1       0
# 4                      0.55  ...                  1               1       1
# ...                     ...  ...                ...             ...     ...
# 50839                  0.10  ...                  0               1       1
# 50840                  0.10  ...                  0               1       1
# 50841                  0.47  ...                  0               1       1
# 50842                  0.21  ...                  0               0       1
# 50843                  0.16  ...                  1               1       1
#
#        Impago  Prima  Tipo_Jornada_Laboral_Desempleado  \
# 0           0   15.0                             False
# 1           1   15.0                             False
# 2           0   15.0                             False
# 3           0   15.0                             False
# 4           0   15.0                             False
# ...       ...    ...                               ...
# 50839       0   15.0                              True
# 50840       0   15.0                              True
# 50841       0   15.0                             False
# 50842       0   15.0                              True
# 50843       0   15.0                              True
#
#        Tipo_Jornada_Laboral_Jornada completa  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                       True
# ...                                      ...
# 50839                                  False
# 50840                                  False
# 50841                                  False
# 50842                                  False
# 50843                                  False
#
#        Tipo_Jornada_Laboral_Tiempo parcial  Estado_Civil_Divorciado  \
# 0                                    False                    False
# 1                                     True                    False
# 2                                     True                    False
# 3                                    False                    False
# 4                                    False                    False
# ...                                    ...                      ...
# 50839                                False                    False
# 50840                                False                    False
# 50841                                False                     True
# 50842                                False                     True
# 50843                                False                    False
#
#        Estado_Civil_Soltero
# 0                      True
# 1                     False
# 2                     False
# 3                     False
# 4                      True
# ...                     ...
# 50839                 False
# 50840                  True
# 50841                 False
# 50842                 False
# 50843                 False
#
# [50844 rows x 21 columns]>

# %%
fig = px.histogram(
    df,
    x="Edad",
    nbins=30,
    title="Distribución de la Edad",
    opacity=0.75
)
fig.update_layout(bargap=0.1)
fig.show()

fig = px.histogram(
    df,
    x="Ingresos",
    nbins=40,
    title="Distribución de Ingresos"
)
fig.show()

# %%
df["Rango_Edad"] = pd.cut(
df["Edad"],
bins=[18, 25, 45, 65, 100],
labels=["18-25", "26-40", "41-65","65+"]
)

# %%
fig = px.box(
    df,
    x="Rango_Edad",
    y="Ingresos",
    title="Ingresos según Rango de Edad"
)
fig.show()

# %%
df_grouped = (
    df.groupby("Rango_Edad")[[
        "Ingresos",
        "Monto_Inicial",
        "Scoring_Crediticio",
        "Ratio_Interes"
    ]]
    .mean()
    .reset_index()
)

fig = px.bar(
    df_grouped,
    x="Rango_Edad",
    y="Scoring_Crediticio",
    title="Scoring Crediticio promedio por Rango de Edad"
)
fig.show()

fig = px.bar(
    df_grouped,
    x="Rango_Edad",
    y="Ingresos",
    title="Ingresos promedio por Rango de Edad"
)
fig.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_7584\827254626.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
import pandas as pd
import plotly.graph_objects as go
from plotly.subplots import make_subplots
from sklearn.preprocessing import MinMaxScaler

# -----------------------------
# 1. Perfiles de edad
# -----------------------------
bins = [18, 29, 39, 49, 59, 100]
labels = ['18-29', '30-39', '40-49', '50-59', '60+']

df = df.copy()
df['Perfil_Edad'] = pd.cut(df['Edad'], bins=bins, labels=labels)

perfiles = df['Perfil_Edad'].dropna().unique()

# -----------------------------
# 2. Columnas (selección robusta)
# -----------------------------
edu_cols   = [c for c in df.columns if c.startswith('Estudios_')]
labor_cols = [c for c in df.columns if c.startswith('Tipo_Jornada_Laboral_')]
civil_cols = [c for c in df.columns if c.startswith('Estado_Civil_')]

fin_cols = [
    'Ingresos',
    'Monto_Inicial',
    'Scoring_Crediticio',
    'Num_Creditos',
    'Ratio_Interes',
    'Ratio_Deuda_Ingresos',
    'Duracion'
]

# Nos quedamos solo con las financieras que existan
fin_cols = [c for c in fin_cols if c in df.columns]

# -----------------------------
# 3. Escalado financiero
# -----------------------------
df_scaled = df.copy()

if fin_cols:
    scaler = MinMaxScaler()
    df_scaled[fin_cols] = scaler.fit_transform(df[fin_cols])

# -----------------------------
# 4. Figura
# -----------------------------
fig = make_subplots(
    rows=2, cols=2,
    specs=[
        [{'type': 'polar'}, {'type': 'polar'}],
        [{'type': 'polar'}, {'type': 'polar'}]
    ],
    subplot_titles=[
        'Nivel de estudios',
        'Situación laboral',
        'Estado civil',
        'Perfil financiero'
    ]
)

traces_per_profile = 4

# -----------------------------
# 5. Trazas por perfil
# -----------------------------
for perfil in perfiles:
    subset = df_scaled[df_scaled['Perfil_Edad'] == perfil]

    # Estudios
    vals = subset[edu_cols].mean().values if edu_cols else []
    fig.add_trace(
        go.Scatterpolar(
            r=list(vals) + ([vals[0]] if len(vals) > 0 else []),
            theta=edu_cols + ([edu_cols[0]] if len(edu_cols) > 0 else []),
            fill='toself',
            visible=False,
            name=str(perfil)
        ),
        row=1, col=1
    )

    # Situación laboral
    vals = subset[labor_cols].mean().values if labor_cols else []
    fig.add_trace(
        go.Scatterpolar(
            r=list(vals) + ([vals[0]] if len(vals) > 0 else []),
            theta=labor_cols + ([labor_cols[0]] if len(labor_cols) > 0 else []),
            fill='toself',
            visible=False
        ),
        row=1, col=2
    )

    # Estado civil
    vals = subset[civil_cols].mean().values if civil_cols else []
    fig.add_trace(
        go.Scatterpolar(
            r=list(vals) + ([vals[0]] if len(vals) > 0 else []),
            theta=civil_cols + ([civil_cols[0]] if len(civil_cols) > 0 else []),
            fill='toself',
            visible=False
        ),
        row=2, col=1
    )

    # Perfil financiero
    vals = subset[fin_cols].mean().values if fin_cols else []
    fig.add_trace(
        go.Scatterpolar(
            r=list(vals) + ([vals[0]] if len(vals) > 0 else []),
            theta=fin_cols + ([fin_cols[0]] if len(fin_cols) > 0 else []),
            fill='toself',
            visible=False
        ),
        row=2, col=2
    )

# -----------------------------
# 6. Mostrar primer perfil
# -----------------------------
for i in range(traces_per_profile):
    fig.data[i].visible = True

# -----------------------------
# 7. Botones
# -----------------------------
buttons = []
total_traces = len(fig.data)

for idx, perfil in enumerate(perfiles):
    visible = [False] * total_traces
    start = idx * traces_per_profile
    end = start + traces_per_profile

    for i in range(start, end):
        visible[i] = True

    buttons.append(
        dict(
            label=str(perfil),
            method='update',
            args=[
                {'visible': visible},
                {'title': f'Perfil de Edad: {perfil}'}
            ]
        )
    )

# -----------------------------
# 8. Layout
# -----------------------------
fig.update_layout(
    height=900,
    title=f'Perfil de Edad: {perfiles[0]}',
    polar=dict(
        radialaxis=dict(
            visible=True,
            range=[0, 1]
        )
    ),
    updatemenus=[
        dict(
            type='buttons',
            direction='down',
            x=-0.30,
            y=0.95,
            buttons=buttons,
            showactive=True
        )
    ]
)

fig.show()

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

sns.set(style="whitegrid", palette="muted")
#

# %%
bins = [18, 25, 35, 45, 60, 100]
labels = ["18-25", "26-35", "36-45", "46-60", "60+"]

df["Rango_Edad"] = pd.cut(df["Edad"], bins=bins, labels=labels, right=True)

# %%
perfil_edad = (
    df.groupby("Rango_Edad")
    .agg(
        Scoring_Medio=("Scoring_Crediticio", "mean"),
        Ingresos_Medios=("Ingresos", "mean"),
        Tasa_Impago=("Impago", "mean")
    )
    .reset_index()
)

plt.figure(figsize=(10,6))
plt.scatter(
    x=perfil_edad["Rango_Edad"],
    y=perfil_edad["Scoring_Medio"],
    s=perfil_edad["Ingresos_Medios"] / 200,
    c=perfil_edad["Tasa_Impago"],
    cmap="Reds",
    alpha=0.7
)

plt.colorbar(label="Tasa de Impago")
plt.xlabel("Rango de Edad")
plt.ylabel("Scoring Crediticio Medio")
plt.title("Perfil financiero por rango de edad")
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_7584\661040484.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
edad_prestamo = (
    df.groupby("Rango_Edad")
    .agg(
        Monto_Medio=("Monto_Inicial", "mean"),
        Duracion_Media=("Duracion", "mean")
    )
    .reset_index()
)

fig, ax1 = plt.subplots(figsize=(10,6))

sns.barplot(
    data=edad_prestamo,
    x="Rango_Edad",
    y="Monto_Medio",
    ax=ax1
)

ax1.set_ylabel("Monto inicial medio")

ax2 = ax1.twinx()
sns.lineplot(
    data=edad_prestamo,
    x="Rango_Edad",
    y="Duracion_Media",
    marker="o",
    color="black",
    ax=ax2
)

ax2.set_ylabel("Duración media (meses)")
plt.title("Monto y duración del préstamo por rango de edad")
plt.show()
# Out:
# C:\Users\sebas\AppData\Local\Temp\ipykernel_7584\3458223140.py:2: FutureWarning:
#
# The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.

# %%
g = sns.displot(
    data=df,
    x="Scoring_Crediticio",
    hue="Impago",
    col="Rango_Edad",
    kind="hist",
    kde=True,
    height=4,
    aspect=1,
    bins=30,
    alpha=0.6
)

g.set_titles("Rango de edad: {col_name}")
g.set_axis_labels("Scoring Crediticio", "Frecuencia")
plt.show()

# %%
vars_pairplot = [
    "Ingresos",
    "Scoring_Crediticio",
    "Ratio_Deuda_Ingresos",
    "Ratio_Interes"
]

sns.pairplot(
    df[vars_pairplot + ["Impago"]],
    hue="Impago",
    diag_kind="kde",
    plot_kws={"alpha": 0.5}
)

plt.show()

# %%
plt.figure(figsize=(10,6))

for rango in df["Rango_Edad"].dropna().unique():
    subset = df[df["Rango_Edad"] == rango]
    sns.kdeplot(
        subset["Ratio_Deuda_Ingresos"],
        label=rango,
        fill=True,
        alpha=0.4
    )

plt.xlabel("Ratio Deuda / Ingresos")
plt.ylabel("Densidad")
plt.title("Distribución del ratio deuda-ingresos por rango de edad")
plt.legend(title="Rango de edad")
plt.show()

# %%
g = sns.relplot(
    data=df,
    x="Ingresos",
    y="Scoring_Crediticio",
    hue="Impago",
    size="Monto_Inicial",
    col="Rango_Edad",
    col_wrap=3,
    alpha=0.6,
    height=4,
    aspect=1,
    sizes=(20, 300)
)

g.set_axis_labels("Ingresos anuales", "Scoring crediticio")
g.set_titles("Rango de edad: {col_name}")
g.fig.suptitle(
    "Relación entre ingresos, scoring e impago por rango de edad",
    y=1.05
)

plt.show()
